# %% [markdown]
# ## About Dataset
# US Minimum Wage by State from 1968 to 2020
#
# #### The Basics
# What is this? In the United States, states and the federal government set minimum hourly pay ("minimum wage") that workers can receive to ensure that citizens experience a minimum quality of life. This dataset provides the minimum wage data set by each state and the federal government from 1968 to 2020.
#
# Why did you put this together? While looking online for a clean dataset for minimum wage data by state, I was having trouble finding one. I decided to create one myself and provide it to the community.
#
# Who do we thank for this data? The United States Department of Labor compiles a table of this data on their website.
#
# Content
# This is a cleaned dataset of US state and federal minimum wages from 1968 to 2020 (including 2020 equivalency values). The data was scraped from the United States Department of Labor's table of minimum wage by state.
#
# #### Description of Data
# The values in the dataset are as follows:
#
# Year: The year of the data. All minimum wage values are as of January 1 except 1968 and 1969, which are as of February 1.
#
# State: The state or territory of the data.
#
# State.Minimum.Wage: The actual State's minimum wage on January 1 of Year.
#
# State.Minimum.Wage.2020.Dollars: The State.Minimum.Wage in 2020 dollars.
#
# Federal.Minimum.Wage: The federal minimum wage on January 1 of Year.
#
# Federal.Minimum.Wage.2020.Dollars: The Federal.Minimum.Wage in 2020 dollars.
#
# Effective.Minimum.Wage: The minimum wage that is enforced in State on January 1 of Year. Because the federal minimum wage takes effect if the State's minimum wage is lower than the federal minimum wage, this is the higher of the two.
#
# Effective.Minimum.Wage.2020.Dollars: The Effective.Minimum.Wage in 2020 dollars.
#
# CPI.Average: The average value of the Consumer Price Index in Year. When I pulled the data from the Bureau of Labor Statistics, I selected the dataset with "all items in U.S. city average, all urban consumers, not seasonally adjusted".
#
# Department.Of.Labor.Uncleaned.Data: The unclean, scraped value from the Department of Labor's website.
#
# Department.Of.Labor.Cleaned.Low.Value: The State's lowest enforced minimum wage on January 1 of Year. If there is only one minimum wage, this and the value for Department.Of.Labor.Cleaned.High.Value are identical. (Some states enforce different minimum wage laws depending on the size of the business. In states where this is the case, generally, smaller businesses have slightly lower minimum wage requirements.)
#
# Department.Of.Labor.Cleaned.Low.Value.2020.Dollars: The Department.Of.Labor.Cleaned.Low.Value in 2020 dollars.
#
# Department.Of.Labor.Cleaned.High.Value: The State's higher enforced minimum wage on January 1 of Year. If there is only one minimum wage, this and the value for Department.Of.Labor.Cleaned.Low.Value are identical.
#
# Department.Of.Labor.Cleaned.High.Value.2020.Dollars: The Department.Of.Labor.Cleaned.High.Value in 2020 dollars.
#
# Footnote: The footnote provided on the Department of Labor's website. See more below.
#
# #### Data Footnotes
# As laws differ significantly from territory to territory, especially relating to whom is protected by minimum wage laws, the following footnotes are located throughout the data in Footnote to add more context to the minimum wage. The original footnotes can be found here.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Minimum_Wage_Data.csv")
# Sometimes when we scrap the data, encoding is different from "utf-8". Pandas use "utf-8" default encoding but when we come across this kind of error, we may need to change the encoding.
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/lq/bb09dcm13557jqlh7zyq8n_c0000gn/T/ipykernel_68374/2567569322.py in <module>
# ----> 1 df = pd.read_csv("Minimum_Wage_Data.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1232
#    1233         try:
# -> 1234             return mapping[engine](f, **self.options)
#    1235         except Exception:
#    1236             if self.handles is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      73
#      74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75         self._reader = parsers.TextReader(src, **kwds)
#      76
#      77         self.unnamed_cols = self._reader.unnamed_cols
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 169202: invalid start byte

# %%
df = pd.read_csv("Minimum_Wage_Data.csv", encoding="latin")
df
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...                               ...                   ...
# 2857                             7.25                  7.25
# 2858                            13.50                  7.25
# 2859                             8.75                  7.25
# 2860                             7.25                  7.25
# 2861                             5.15                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                  8.55                    1.15
# 1                                  8.55                    2.10
# 2                                  8.55                    1.15
# 3                                  8.55                    1.15
# 4                                  8.55                    1.65
# ...                                 ...                     ...
# 2857                               7.25                    7.25
# 2858                               7.25                   13.50
# 2859                               7.25                    8.75
# 2860                               7.25                    7.25
# 2861                               7.25                    7.25
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                    8.55        34.80
# 1                                   15.61        34.80
# 2                                    8.55        34.80
# 3                                    8.55        34.80
# 4                                   12.26        34.80
# ...                                   ...          ...
# 2857                                 7.25       258.66
# 2858                                13.50       258.66
# 2859                                 8.75       258.66
# 2860                                 7.25       258.66
# 2861                                 7.25       258.66
#
#      Department.Of.Labor.Uncleaned.Data  \
# 0                                   ...
# 1                                   2.1
# 2                   18.72 - 26.40/wk(b)
# 3                           1.25/day(b)
# 4                               1.65(b)
# ...                                 ...
# 2857                            7.25[c]
# 2858                               13.5
# 2859                               8.75
# 2860                               7.25
# 2861                               5.15
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# 0                                   0.00000
# 1                                   2.10000
# 2                                   0.46800
# 3                                   0.15625
# 4                                   1.65000
# ...                                     ...
# 2857                                7.25000
# 2858                               13.50000
# 2859                                8.75000
# 2860                                7.25000
# 2861                                5.15000
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.00
# 1                                                 15.61
# 2                                                  3.48
# 3                                                  1.16
# 4                                                 12.26
# ...                                                 ...
# 2857                                               7.25
# 2858                                              13.50
# 2859                                               8.75
# 2860                                               7.25
# 2861                                               5.15
#
#       Department.Of.Labor.Cleaned.High.Value  \
# 0                                    0.00000
# 1                                    2.10000
# 2                                    0.66000
# 3                                    0.15625
# 4                                    1.65000
# ...                                      ...
# 2857                                 7.25000
# 2858                                13.50000
# 2859                                 8.75000
# 2860                                 7.25000
# 2861                                 5.15000
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.00        NaN
# 1                                                 15.61        NaN
# 2                                                  4.91        (b)
# 3                                                  1.16        (b)
# 4                                                 12.26        (b)
# ...                                                 ...        ...
# 2857                                               7.25        [c]
# 2858                                              13.50        NaN
# 2859                                               8.75        NaN
# 2860                                               7.25        NaN
# 2861                                               5.15        NaN
#
# [2862 rows x 15 columns]

# %% [markdown]
# **This is not standard practice so it's better to convert export this csv in "utf-8" encoding**

# %%
df.to_csv("minwage.csv", encoding="utf-8")

# %%
df = pd.read_csv("minwage.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# 3                               8.55                    1.15
# 4                               8.55                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                 8.55         34.8
# 1                                15.61         34.8
# 2                                 8.55         34.8
# 3                                 8.55         34.8
# 4                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# 1971                               8.30                    1.30
# 1972                               9.90                    1.60
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# Year
# 1968                                 8.55         34.8
# 1969                                 8.11         36.7
# 1970                                 8.67         38.8
# 1971                                 8.30         40.5
# 1972                                 9.90         41.8
#
#      Department.Of.Labor.Uncleaned.Data  \
# Year
# 1968                                ...
# 1969                                ...
# 1970                                ...
# 1971                                ...
# 1972                                ...
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# Year
# 1968                                    0.0
# 1969                                    0.0
# 1970                                    0.0
# 1971                                    0.0
# 1972                                    0.0
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# Year
# 1968                                                0.0
# 1969                                                0.0
# 1970                                                0.0
# 1971                                                0.0
# 1972                                                0.0
#
#       Department.Of.Labor.Cleaned.High.Value  \
# Year
# 1968                                     0.0
# 1969                                     0.0
# 1970                                     0.0
# 1971                                     0.0
# 1972                                     0.0
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# Year
# 1968                                                0.0        NaN
# 1969                                                0.0        NaN
# 1970                                                0.0        NaN
# 1971                                                0.0        NaN
# 1972                                                0.0        NaN

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# 3                               8.55                    1.15
# 4                               8.55                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                 8.55         34.8
# 1                                15.61         34.8
# 2                                 8.55         34.8
# 3                                 8.55         34.8
# 4                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %% [markdown]
# **Now if you see the "state" column, we have different state and at the same time we have many years which starts from 1968 to 2019. Now I want all state values in column and "Year" as index. Basically I want all the state in columns.**
#
# **Now to do that I need to first create a empty data frame and then iterate through "df" and create dataframe of each state and save it into empty dataframe**

# %%
act_min_wage = pd.DataFrame() # empty data frame

# %%
for name, group in df.groupby("State"): # name = "state name", group is dataframe of that state. 
      if act_min_wage.empty:
            act_min_wage = group.set_index("Year")[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name})
      else:
            act_min_wage = act_min_wage.join(group.set_index("Year")[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name}))

# %%
act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969      0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970      0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971      0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972      0.0   12.99     2.90      7.43       10.21      6.19        11.45
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      9.29                  9.29      0.0  ...        0.0   0.00
# 1969      8.81                  8.81      0.0  ...        0.0   0.00
# 1970      8.33                 10.67      0.0  ...        0.0   0.00
# 1971      7.98                 10.22      0.0  ...        0.0   0.00
# 1972      9.90                  9.90      0.0  ...        0.0   8.66
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  0.0  7.43    10.41       0.0       11.89           7.43
# 1969                  0.0  7.05     9.87       0.0       11.28           7.05
# 1970                  0.0  6.67    10.67       0.0       10.67           6.67
# 1971                  0.0  6.39    10.22       0.0       10.22           6.39
# 1972                  0.0  7.43     9.90       0.0        9.90           7.43
#
#       Wisconsin  Wyoming
# Year
# 1968       9.29     8.92
# 1969       8.81     8.46
# 1970       8.67     8.67
# 1971       8.30     8.30
# 1972       8.97     9.28
#
# [5 rows x 54 columns]

# %% [markdown]
# same logic different code appraoching. Let's see

# %%
df
# Out:
#       Unnamed: 0  Year          State  State.Minimum.Wage  \
# 0              0  1968        Alabama             0.00000
# 1              1  1968         Alaska             2.10000
# 2              2  1968        Arizona             0.46800
# 3              3  1968       Arkansas             0.15625
# 4              4  1968     California             1.65000
# ...          ...   ...            ...                 ...
# 2857        2857  2020       Virginia             7.25000
# 2858        2858  2020     Washington            13.50000
# 2859        2859  2020  West Virginia             8.75000
# 2860        2860  2020      Wisconsin             7.25000
# 2861        2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...                               ...                   ...
# 2857                             7.25                  7.25
# 2858                            13.50                  7.25
# 2859                             8.75                  7.25
# 2860                             7.25                  7.25
# 2861                             5.15                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                  8.55                    1.15
# 1                                  8.55                    2.10
# 2                                  8.55                    1.15
# 3                                  8.55                    1.15
# 4                                  8.55                    1.65
# ...                                 ...                     ...
# 2857                               7.25                    7.25
# 2858                               7.25                   13.50
# 2859                               7.25                    8.75
# 2860                               7.25                    7.25
# 2861                               7.25                    7.25
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                    8.55        34.80
# 1                                   15.61        34.80
# 2                                    8.55        34.80
# 3                                    8.55        34.80
# 4                                   12.26        34.80
# ...                                   ...          ...
# 2857                                 7.25       258.66
# 2858                                13.50       258.66
# 2859                                 8.75       258.66
# 2860                                 7.25       258.66
# 2861                                 7.25       258.66
#
#      Department.Of.Labor.Uncleaned.Data  \
# 0                                   ...
# 1                                   2.1
# 2                   18.72 - 26.40/wk(b)
# 3                           1.25/day(b)
# 4                               1.65(b)
# ...                                 ...
# 2857                            7.25[c]
# 2858                               13.5
# 2859                               8.75
# 2860                               7.25
# 2861                               5.15
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# 0                                   0.00000
# 1                                   2.10000
# 2                                   0.46800
# 3                                   0.15625
# 4                                   1.65000
# ...                                     ...
# 2857                                7.25000
# 2858                               13.50000
# 2859                                8.75000
# 2860                                7.25000
# 2861                                5.15000
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.00
# 1                                                 15.61
# 2                                                  3.48
# 3                                                  1.16
# 4                                                 12.26
# ...                                                 ...
# 2857                                               7.25
# 2858                                              13.50
# 2859                                               8.75
# 2860                                               7.25
# 2861                                               5.15
#
#       Department.Of.Labor.Cleaned.High.Value  \
# 0                                    0.00000
# 1                                    2.10000
# 2                                    0.66000
# 3                                    0.15625
# 4                                    1.65000
# ...                                      ...
# 2857                                 7.25000
# 2858                                13.50000
# 2859                                 8.75000
# 2860                                 7.25000
# 2861                                 5.15000
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.00        NaN
# 1                                                 15.61        NaN
# 2                                                  4.91        (b)
# 3                                                  1.16        (b)
# 4                                                 12.26        (b)
# ...                                                 ...        ...
# 2857                                               7.25        [c]
# 2858                                              13.50        NaN
# 2859                                               8.75        NaN
# 2860                                               7.25        NaN
# 2861                                               5.15        NaN
#
# [2862 rows x 16 columns]

# %%
min_wage = pd.DataFrame()

# %%
for name, group in df.groupby("State"):
    if min_wage.empty:
        min_wage = group[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name}).set_index("Year")
    else:
        min_wage = min_wage.join(group[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name})).set_index("Year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lq/bb09dcm13557jqlh7zyq8n_c0000gn/T/ipykernel_68374/4112905593.py in <module>
#       1 for name, group in df.groupby("State"):
#       2     if min_wage.empty:
# ----> 3         min_wage = group[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name}).set_index("Year")
#       4     else:
#       5         min_wage = min_wage.join(group[["State.Minimum.Wage.2020.Dollars"]].rename(columns={"State.Minimum.Wage.2020.Dollars":name})).set_index("Year")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Year'] are in the columns"

# %% [markdown]
# In above code, we are taking only 1 column and then setting index as "year". That's why python is giving error that "Year" column not exist.

# %%
act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969      0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970      0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971      0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972      0.0   12.99     2.90      7.43       10.21      6.19        11.45
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      9.29                  9.29      0.0  ...        0.0   0.00
# 1969      8.81                  8.81      0.0  ...        0.0   0.00
# 1970      8.33                 10.67      0.0  ...        0.0   0.00
# 1971      7.98                 10.22      0.0  ...        0.0   0.00
# 1972      9.90                  9.90      0.0  ...        0.0   8.66
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  0.0  7.43    10.41       0.0       11.89           7.43
# 1969                  0.0  7.05     9.87       0.0       11.28           7.05
# 1970                  0.0  6.67    10.67       0.0       10.67           6.67
# 1971                  0.0  6.39    10.22       0.0       10.22           6.39
# 1972                  0.0  7.43     9.90       0.0        9.90           7.43
#
#       Wisconsin  Wyoming
# Year
# 1968       9.29     8.92
# 1969       8.81     8.46
# 1970       8.67     8.67
# 1971       8.30     8.30
# 1972       8.97     9.28
#
# [5 rows x 54 columns]

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   9.917736   2.917358   7.139245    9.101132   6.881698
# std        0.0   1.852213   4.102247   1.459132    1.418712   1.921086
# min        0.0   7.620000   0.000000   1.100000    6.630000   3.970000
# 25%        0.0   8.590000   0.000000   6.780000    8.000000   5.250000
# 50%        0.0   9.260000   0.000000   7.210000    9.010000   6.670000
# 75%        0.0  10.510000   8.290000   7.740000    9.710000   8.430000
# max        0.0  15.610000  12.140000  10.000000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   7.818679              8.919245   2.415283  ...
# std       1.106907   1.307834              1.932959   3.882305  ...
# min       7.040000   4.550000              5.690000   0.000000  ...
# 25%       8.200000   7.320000              7.420000   0.000000  ...
# 50%       9.430000   8.170000              8.840000   0.000000  ...
# 75%       9.870000   8.620000              9.600000   8.210000  ...
# max      11.450000   9.900000             14.160000   8.790000  ...
#
#        Tennessee      Texas  U.S. Virgin Islands       Utah    Vermont  \
# count       53.0  53.000000            53.000000  53.000000  53.000000
# mean         0.0   5.816038             5.531509   7.079245   9.057358
# std          0.0   2.240879             3.281419   0.824707   1.093119
# min          0.0   0.000000             0.000000   4.950000   7.030000
# 25%          0.0   4.990000             4.630000   6.610000   8.060000
# 50%          0.0   6.360000             6.040000   7.220000   9.240000
# 75%          0.0   7.350000             7.910000   7.660000   9.820000
# max          0.0   8.660000            10.620000   8.600000  11.090000
#
#         Virginia  Washington  West Virginia  Wisconsin    Wyoming
# count  53.000000   53.000000      53.000000  53.000000  53.000000
# mean    6.163019    8.826038       7.486226   7.914528   5.313208
# std     2.749633    2.147933       0.866017   0.778113   2.004899
# min     0.000000    4.550000       5.770000   6.630000   2.340000
# 25%     6.250000    7.610000       6.850000   7.320000   3.500000
# 50%     7.210000    9.700000       7.370000   7.810000   5.550000
# 75%     7.810000   10.180000       7.930000   8.340000   6.820000
# max     9.090000   13.660000       9.430000   9.980000   9.280000
#
# [8 rows x 54 columns]

# %%
act_min_wage.corr().head() # So basically we are comapring different states with each other
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.037101 -0.332127    0.622245 -0.078678
# Arizona         NaN  0.037101  1.000000  0.271834    0.639006  0.820730
# Arkansas        NaN -0.332127  0.271834  1.000000    0.030265  0.333597
# California      NaN  0.622245  0.639006  0.030265    1.000000  0.649967
#
#             Connecticut  Delaware  District of Columbia   Florida  ...  \
# Alabama             NaN       NaN                   NaN       NaN  ...
# Alaska         0.646909  0.260265              0.271810 -0.193062  ...
# Arizona        0.555455  0.477781              0.723523  0.907295  ...
# Arkansas       0.183662  0.107639              0.433775  0.340509  ...
# California     0.881831  0.518481              0.727373  0.443946  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# Alabama           NaN       NaN                  NaN       NaN       NaN
# Alaska            NaN -0.507366            -0.609398 -0.017546  0.615675
# Arizona           NaN  0.398732            -0.115225  0.413915  0.624314
# Arkansas          NaN  0.520381             0.332492  0.208586  0.236875
# California        NaN -0.109316            -0.236033  0.367924  0.894617
#
#             Virginia  Washington  West Virginia  Wisconsin   Wyoming
# Alabama          NaN         NaN            NaN        NaN       NaN
# Alaska     -0.593675    0.378141       0.056924   0.683108  0.726771
# Arizona     0.096048    0.691863       0.663311   0.014723  0.288171
# Arkansas    0.572595    0.130825       0.504703  -0.069024 -0.235369
# California -0.216247    0.816087       0.492809   0.382444  0.598739
#
# [5 rows x 54 columns]

# %%
# lets create data frame where we can see the all null values

issue_df = df[df["State.Minimum.Wage.2020.Dollars"] == 0]
issue_df.head()
# Out:
#     Unnamed: 0  Year     State  State.Minimum.Wage  \
# 0            0  1968   Alabama                 0.0
# 9            9  1968   Florida                 0.0
# 10          10  1968   Georgia                 0.0
# 14          14  1968  Illinois                 0.0
# 16          16  1968      Iowa                 0.0
#
#     State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                               0.0                  1.15
# 9                               0.0                  1.15
# 10                              0.0                  1.15
# 14                              0.0                  1.15
# 16                              0.0                  1.15
#
#     Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                8.55                    1.15
# 9                                8.55                    1.15
# 10                               8.55                    1.15
# 14                               8.55                    1.15
# 16                               8.55                    1.15
#
#     Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                  8.55         34.8
# 9                                  8.55         34.8
# 10                                 8.55         34.8
# 14                                 8.55         34.8
# 16                                 8.55         34.8
#
#    Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                 ...                                    0.0
# 9                                 ...                                    0.0
# 10                                ...                                    0.0
# 14                                ...                                    0.0
# 16                                ...                                    0.0
#
#     Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# 14                                                0.0
# 16                                                0.0
#
#     Department.Of.Labor.Cleaned.High.Value  \
# 0                                      0.0
# 9                                      0.0
# 10                                     0.0
# 14                                     0.0
# 16                                     0.0
#
#     Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                 0.0        NaN
# 9                                                 0.0        NaN
# 10                                                0.0        NaN
# 14                                                0.0        NaN
# 16                                                0.0        NaN

# %%
issue_df["State"].unique() # These are the states where we Null values are present
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'U.S. Virgin Islands',
#        'Virginia', 'Arizona', 'Puerto Rico'], dtype=object)

# %% [markdown]
# Let's replace "0" with np.Nan

# %%
import numpy as np
act_min_wage.replace(0, np.NaN).dropna(axis=1).head()
# Out:
#       Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Year
# 1968   15.61      1.16       12.26      7.43        10.41      9.29
# 1969   14.80      1.10       11.63      7.05         9.87      8.81
# 1970   14.00      7.33       11.00      6.67        10.67      8.33
# 1971   13.41      7.03       10.54      6.39        10.22      7.98
# 1972   12.99      7.43       10.21      6.19        11.45      9.90
#
#       District of Columbia   Guam  Hawaii  Idaho  ...  Oregon  Pennsylvania  \
# Year                                              ...
# 1968                  9.29   9.29    9.29   8.55  ...    9.29          8.55
# 1969                  8.81   8.81    8.81   8.11  ...    8.81          8.11
# 1970                 10.67  10.67   10.67   8.33  ...    8.33          8.67
# 1971                 10.22  10.22   10.22   7.98  ...    7.98          8.30
# 1972                  9.90  11.76    9.90   8.66  ...    7.74          9.90
#
#       Rhode Island  South Dakota  Utah  Vermont  Washington  West Virginia  \
# Year
# 1968         10.41          3.16  7.43    10.41       11.89           7.43
# 1969          9.87          3.00  7.05     9.87       11.28           7.05
# 1970         10.67          6.67  6.67    10.67       10.67           6.67
# 1971         10.22          6.39  6.39    10.22       10.22           6.39
# 1972          9.90          6.19  7.43     9.90        9.90           7.43
#
#       Wisconsin  Wyoming
# Year
# 1968       9.29     8.92
# 1969       8.81     8.46
# 1970       8.67     8.67
# 1971       8.30     8.30
# 1972       8.97     9.28
#
# [5 rows x 37 columns]

# %% [markdown]
# **Here comes a problem. Many state may not have minimun wage in 1968 but later that state may have started min_wage**

# %%
grouped_issues = issue_df.groupby("State")

# %%
grouped_issues.get_group("Alabama").head()
# Out:
#      Unnamed: 0  Year    State  State.Minimum.Wage  \
# 0             0  1968  Alabama                 0.0
# 54           54  1969  Alabama                 0.0
# 108         108  1970  Alabama                 0.0
# 162         162  1971  Alabama                 0.0
# 216         216  1972  Alabama                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.0                  1.15
# 54                               0.0                  1.15
# 108                              0.0                  1.30
# 162                              0.0                  1.30
# 216                              0.0                  1.60
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                 8.55                    1.15
# 54                                8.11                    1.15
# 108                               8.67                    1.30
# 162                               8.30                    1.30
# 216                               9.90                    1.60
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                   8.55         34.8
# 54                                  8.11         36.7
# 108                                 8.67         38.8
# 162                                 8.30         40.5
# 216                                 9.90         41.8
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                  ...                                    0.0
# 54                                 ...                                    0.0
# 108                                ...                                    0.0
# 162                                ...                                    0.0
# 216                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.0
# 54                                                 0.0
# 108                                                0.0
# 162                                                0.0
# 216                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 0                                       0.0
# 54                                      0.0
# 108                                     0.0
# 162                                     0.0
# 216                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.0        NaN
# 54                                                 0.0        NaN
# 108                                                0.0        NaN
# 162                                                0.0        NaN
# 216                                                0.0        NaN

# %%
grouped_issues.get_group("Alabama")["State.Minimum.Wage.2020.Dollars"].sum()
# basically all the rows of Alabama in column ""State.Minimum.Wage.2020.Dollars"" is 0
# Out:
# 0.0

# %%
issue_df["State"].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'U.S. Virgin Islands',
#        'Virginia', 'Arizona', 'Puerto Rico'], dtype=object)

# %%
grouped_issues.get_group("Florida")["State.Minimum.Wage.2020.Dollars"].sum()
# Out:
# 0.0

# %%
grouped_issues.get_group("Florida")["State.Minimum.Wage.2020.Dollars"].sum()
# Out:
# 0.0

# %%
issue_df["State"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/lq/bb09dcm13557jqlh7zyq8n_c0000gn/T/ipykernel_68374/3669763835.py in <module>
# ----> 1 issue_df["State"].plot()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     325     def generate(self):
#     326         self._args_adjust()
# --> 327         self._compute_plot_data()
#     328         self._setup_subplots()
#     329         self._make_plot()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     504         # no non-numeric frames or series allowed
#     505         if is_empty:
# --> 506             raise TypeError("no numeric data to plot")
#     507
#     508         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
grouped_issues.get_group("Texas")[["State.Minimum.Wage.2020.Dollars","Federal.Minimum.Wage.2020.Dollars"]].plot(label=['State Minimum Wage', 'Federal Minimum Wage'], figsize=(16,5))
# Out:
# <AxesSubplot:>

# %%
grouped_issues.get_group("Texas")[["State.Minimum.Wage.2020.Dollars"]].plot(label=['State Minimum Wage'], figsize=(16,5))
# Out:
# <AxesSubplot:>

# %%
grouped_issues.get_group("Texas").plot(y =["State.Minimum.Wage.2020.Dollars","Federal.Minimum.Wage.2020.Dollars"],x = "Year",label=['State Minimum Wage', 'Federal Minimum Wage'], figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Out:
#      Unnamed: 0  Year  State  State.Minimum.Wage  \
# 45           45  1968  Texas                 0.0
# 99           99  1969  Texas                 0.0
# 153         153  1970  Texas                 0.0
# 207         207  1971  Texas                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 45                               0.0                  1.15
# 99                               0.0                  1.15
# 153                              0.0                  1.30
# 207                              0.0                  1.30
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 45                                8.55                    1.15
# 99                                8.11                    1.15
# 153                               8.67                    1.30
# 207                               8.30                    1.30
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 45                                  8.55         34.8
# 99                                  8.11         36.7
# 153                                 8.67         38.8
# 207                                 8.30         40.5
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 45                                 ...                                    0.0
# 99                                 ...                                    0.0
# 153                                ...                                    0.0
# 207                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 45                                                 0.0
# 99                                                 0.0
# 153                                                0.0
# 207                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 45                                      0.0
# 99                                      0.0
# 153                                     0.0
# 207                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 45                                                 0.0        NaN
# 99                                                 0.0        NaN
# 153                                                0.0        NaN
# 207                                                0.0        NaN

# %% [markdown]
# **So now lets iterate through "gropued_issue" to see if there are any non zero values present or not.**

# %%
for state, data in grouped_issues:
    print(state)
# Out:
# Alabama
# Arizona
# Florida
# Georgia
# Illinois
# Iowa
# Kansas
# Louisiana
# Mississippi
# Missouri
# Montana
# Puerto Rico
# South Carolina
# Tennessee
# Texas
# U.S. Virgin Islands
# Virginia

# %%
for state, data in grouped_issues:
    print(data)
# Out:
#       Unnamed: 0  Year    State  State.Minimum.Wage  \
# 0              0  1968  Alabama                 0.0
# 54            54  1969  Alabama                 0.0
# 108          108  1970  Alabama                 0.0
# 162          162  1971  Alabama                 0.0
# 216          216  1972  Alabama                 0.0
# 270          270  1973  Alabama                 0.0
# 324          324  1974  Alabama                 0.0
# 378          378  1975  Alabama                 0.0
# 432          432  1976  Alabama                 0.0
# 486          486  1977  Alabama                 0.0
# 540          540  1978  Alabama                 0.0
# 594          594  1979  Alabama                 0.0
# 648          648  1980  Alabama                 0.0
# 702          702  1981  Alabama                 0.0
# 756          756  1982  Alabama                 0.0
# 810          810  1983  Alabama                 0.0
# 864          864  1984  Alabama                 0.0
# 918          918  1985  Alabama                 0.0
# 972          972  1986  Alabama                 0.0
# 1026        1026  1987  Alabama                 0.0
# 1080        1080  1988  Alabama                 0.0
# 1134        1134  1989  Alabama                 0.0
# 1188        1188  1990  Alabama                 0.0
# 2376                                                0.0
# 2430                                                0.0
# 2484                                                0.0
# 2538                                                0.0
# 2592                                                0.0
# 2646                                                0.0
# 2700                                                0.0
# 2754                                                0.0
# 2808                                                0.0
#
#       Department.Of.Labor.Cleaned.High.Value  \
# 0                                        0.0
# 54                                       0.0
# 108                                      0.0
# 162                                      0.0
# 216                                      0.0
# 270                                      0.0
# 324                                      0.0
# 378                                      0.0
# 432                                      0.0
# 486                                      0.0
# 540                                      0.0
# 594                                      0.0
# 648                                      0.0
# 702                                      0.0
# 756                                      0.0
# 810                                      0.0
# 864                                      0.0
# 918                                      0.0
# 972                                      0.0
# 1026                                     0.0
# 1080                                     0.0
# 1134                                     0.0
# 1188                                     0.0
# 1242                                     0.0
# 1296                                     0.0
# 1350                                     0.0
# 1404                                     0.0
# 1458                                     0.0
# 1512                                     0.0
# 1566                                     0.0
# 1620                                     0.0
# 1674                                     0.0
# 1728                                     0.0
# 1782                                     0.0
# 1836                                     0.0
# 1890                                     0.0
# 1944                                     0.0
# 1998                                     0.0
# 2052                                     0.0
# 2106                                     0.0
# 2160                                     0.0
# 2214                                     0.0
# 2268                                     0.0
# 2322                                     0.0
# 2376                                     0.0
# 2430                                     0.0
# 2484                                     0.0
# 2538                                     0.0
# 2592                                     0.0
# 2646                                     0.0
# 2700                                     0.0
# 2754                                     0.0
# 2808                                     0.0
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                   0.0        NaN
# 54                                                  0.0        NaN
# 108                                                 0.0        NaN
# 162                                                 0.0        NaN
# 216                                                 0.0        NaN
# 270                                                 0.0        NaN
# 324                                                 0.0        NaN
# 378                                                 0.0        NaN
# 432                                                 0.0        NaN
# 486                                                 0.0        NaN
# 540                                                 0.0        NaN
# 594                                                 0.0        NaN
# 648                                                 0.0        NaN
# 702                                                 0.0        NaN
# 756                                                 0.0        NaN
# 810                                                 0.0        NaN
# 864                                                 0.0        NaN
# 918                                                 0.0        NaN
# 972                                                 0.0        NaN
# 1026                                                0.0        NaN
# 1080                                                0.0        NaN
# 1134                                                0.0        NaN
# 1188                                                0.0        NaN
# 1242                                                0.0        NaN
# 1296                                                0.0        NaN
# 1350                                                0.0        NaN
# 1404                                                0.0        NaN
# 1458                                                0.0        NaN
# 1512                                                0.0        NaN
# 1566                                                0.0        NaN
# 1620                                                0.0        NaN
# 1674                                                0.0        NaN
# 1728                                                0.0        NaN
# 1782                                                0.0        NaN
# 1836                                                0.0        NaN
# 1890                                                0.0        NaN
# 1944                                                0.0        NaN
# 1998                                                0.0        NaN
# 2052                                                0.0        NaN
# 2106                                                0.0        NaN
# 2160                                                0.0        NaN
# 2214                                                0.0        NaN
# 2268                                                0.0        NaN
# 2322                                                0.0        NaN
# 2376                                                0.0        NaN
# 2430                                                0.0        NaN
# 2484                                                0.0        NaN
# 2538                                                0.0        NaN
# 2592                                                0.0        NaN
# 2646                                                0.0        NaN
# 2700                                                0.0        NaN
# 2754                                                0.0        NaN
# 2808                                                0.0        NaN
#       Unnamed: 0  Year    State  State.Minimum.Wage  \
#       Department.Of.Labor.Cleaned.High.Value  \
# 434                                      0.0
# 488                                      0.0
# 542                                      0.0
# 596                                      0.0
# 650                                      0.0
# 704                                      0.0
# 758                                      0.0
# 812                                      0.0
# 866                                      0.0
# 920                                      0.0
# 974                                      0.0
# 1028                                     0.0
# 1082                                     0.0
# 1136                                     0.0
# 1190                                     0.0
# 1244                                     0.0
# 1298                                     0.0
# 1352                                     0.0
# 1406                                     0.0
# 1460                                     0.0
# 1514                                     0.0
# 1568                                     0.0
# 1622                                     0.0
# 1676                                     0.0
# 1730                                     0.0
# 1784                                     0.0
# 1838                                     0.0
# 1892                                     0.0
# 1946                                     0.0
# 2000                                     0.0
# 2054                                     0.0
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 434                                                 0.0        NaN
# 488                                                 0.0        NaN
# 542                                                 0.0        NaN
# 596                                                 0.0        NaN
# 650                                                 0.0        NaN
# 704                                                 0.0        NaN
# 758                                                 0.0        NaN
# 812                                                 0.0        NaN
# 866                                                 0.0        NaN
# 920                                                 0.0        NaN
# 974                                                 0.0        NaN
# 1028                                                0.0        NaN
# 1082                                                0.0        NaN
# 1136                                                0.0        NaN
# 1190                                                0.0        NaN
# 1244                                                0.0        NaN
# 1298                                                0.0        NaN
# 1352                                                0.0        NaN
# 1406                                                0.0        NaN
# 1460                                                0.0        NaN
# 1514                                                0.0        NaN
# 1568                                                0.0        NaN
# 1622                                                0.0        NaN
# 1676                                                0.0        NaN
# 1730                                                0.0        NaN
# 1784                                                0.0        NaN
# 1838                                                0.0        NaN
# 1892                                                0.0        NaN
# 1946                                                0.0        NaN
# 2000                                                0.0        NaN
# 2054                                                0.0        NaN
#       Unnamed: 0  Year    State  State.Minimum.Wage  \
# 9              9  1968  Florida                 0.0
# 63            63  1969  Florida                 0.0
# 117          117  1970  Florida                 0.0
# 171          171  1971  Florida                 0.0
# 225          225  1972  Florida                 0.0
# 279          279  1973  Florida                 0.0
# 333          333  1974  Florida                 0.0
# 387          387  1975  Florida                 0.0
# 441          441  1976  Florida                 0.0
# 495          495  1977  Florida                 0.0
# 549          549  1978  Florida                 0.0
# 603          603  1979  Florida                 0.0
# 657          657  1980  Florida                 0.0
# 711          711  1981  Florida                 0.0
# 765          765  1982  Florida                 0.0
# 819          819  1983  Florida                 0.0
# 873          873  1984  Florida                 0.0
# 927          927  1985  Florida                 0.0
# 981          981  1986  Florida                 0.0
# 1035        1035  1987  Florida                 0.0
# 1089        1089  1988  Florida                 0.0
# 1143        1143  1989  Florida                 0.0
# 1197        1197  1990  Florida                 0.0
# 1251        1251  1991  Florida                 0.0
# 1305        1305  1992  Florida                 0.0
# 1359        1359  1993  Florida                 0.0
# 1413        1413  1994  Florida                 0.0
# 1467        1467  1995  Florida                 0.0
# 1521        1521  1996  Florida                 0.0
# 1575        1575  1997  Florida                 0.0
# 1629        1629  1998  Florida                 0.0
# 1683        1683  1999  Florida                 0.0
# 1737        1737  2000  Florida                 0.0
# 1791        1791  2001  Florida                 0.0
# 1845        1845  2002  Florida                 0.0
# 1899        1899  2003  Florida                 0.0
# 1953        1953  2004  Florida                 0.0
# 2007        2007  2005  Florida                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 9                                 0.0                  1.15
# 63                                0.0                  1.15
# 117                               0.0                  1.30
# 171                               0.0                  1.30
# 225                               0.0                  1.60
# 279                               0.0                  1.60
# 333                               0.0                  1.60
# 387                               0.0                  1.60
# 441                               0.0                  2.20
# 495                               0.0                  2.20
# 549                               0.0                  2.20
# 603                               0.0                  2.90
# 657                               0.0                  3.10
# 711                               0.0                  3.35
# 765                               0.0                  3.35
# 819                               0.0                  3.35
# 873                               0.0                  3.35
# 927                               0.0                  3.35
# 981                               0.0                  3.35
# 1035                              0.0                  3.35
# 1089                              0.0                  3.35
# 1143                              0.0                  3.35
# 1197                              0.0                  3.35
# 1251                              0.0                  3.80
# 1305                              0.0                  4.25
# 1359                              0.0                  4.25
# 1413                              0.0                  4.25
# 1467                              0.0                  4.25
# 1521                              0.0                  4.25
# 1575                              0.0                  4.75
# ...
# 584                                                 0.0        NaN
# 638                                                 0.0        NaN
# 692                                                 0.0        NaN
# 746                                                 0.0        NaN
# 800                                                 0.0        NaN
# 854                                                 0.0        NaN
# 908                                                 0.0        NaN
# 962                                                 0.0        NaN
# 1016                                                0.0        NaN
# 1070                                                0.0        NaN
# 1124                                                0.0        NaN
# 1178                                                0.0        NaN
# 1232                                                0.0        NaN
# 1286                                                0.0        NaN
# 1340                                                0.0        NaN
# 1394                                                0.0        NaN
# 1448                                                0.0        NaN
# 1502                                                0.0        NaN
# 1556                                                0.0        NaN
# 1610                                                0.0        NaN
# 1664                                                0.0        NaN
# 1718                                                0.0        NaN
# 1772                                                0.0        NaN
# 1826                                                0.0        NaN
# 1880                                                0.0        NaN
# 1934                                                0.0        NaN
# 1988                                                0.0        NaN
# 2042                                                0.0        NaN
# 2096                                                0.0        NaN
# 2150                                                0.0        NaN
# 2204                                                0.0        NaN
# 2258                                                0.0        NaN
# 2312                                                0.0        NaN
# 2366                                                0.0        NaN
# 2420                                                0.0        NaN
# 2474                                                0.0        NaN
# 2528                                                0.0        NaN
# 2582                                                0.0        NaN
# 2636                                                0.0        NaN
# 2690                                                0.0        NaN
# 2744                                                0.0        NaN
# 2798                                                0.0        NaN
# 2852                                                0.0        NaN
#      Unnamed: 0  Year  State  State.Minimum.Wage  \
# 45           45  1968  Texas                 0.0
# 99           99  1969  Texas                 0.0
# 153         153  1970  Texas                 0.0
# 207         207  1971  Texas                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 45                               0.0                  1.15
# 99                               0.0                  1.15
# 153                              0.0                  1.30
# 207                              0.0                  1.30
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 45                                8.55                    1.15
# 99                                8.11                    1.15
# 153                               8.67                    1.30
# 207                               8.30                    1.30
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 45                                  8.55         34.8
# 99                                  8.11         36.7
# 153                                 8.67         38.8
# 207                                 8.30         40.5
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 45                                 ...                                    0.0
# 99                                 ...                                    0.0
# 153                                ...                                    0.0
# 207                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 45                                                 0.0
# 99                                                 0.0
# 153                                                0.0
# 207                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 45                                      0.0
# 99                                      0.0
# 153                                     0.0
# 207                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 45                                                 0.0        NaN
# 99                                                 0.0        NaN
# 153                                                0.0        NaN
# 207                                                0.0        NaN
#      Unnamed: 0  Year                State  State.Minimum.Wage  \
# 46           46  1968  U.S. Virgin Islands                 0.0
# 100         100  1969  U.S. Virgin Islands                 0.0
# 154         154  1970  U.S. Virgin Islands                 0.0
# 208         208  1971  U.S. Virgin Islands                 0.0
# 262         262  1972  U.S. Virgin Islands                 0.0
# 316         316  1973  U.S. Virgin Islands                 0.0
# 370         370  1974  U.S. Virgin Islands                 0.0
# 424         424  1975  U.S. Virgin Islands                 0.0
# 478         478  1976  U.S. Virgin Islands                 0.0
# 532         532  1977  U.S. Virgin Islands                 0.0
# 586         586  1978  U.S. Virgin Islands                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 46                               0.0                  1.15
# 100                              0.0                  1.15
# 154                              0.0                  1.30
# 208                              0.0                  1.30
# 262                              0.0                  1.60
# 316                              0.0                  1.60
# 370                              0.0                  1.60
# 424                              0.0                  1.60
# 478                              0.0                  2.20
# 532                              0.0                  2.20
# 586                              0.0                  2.20
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 46                                8.55                    1.15
# 100                               8.11                    1.15
# 154                               8.67                    1.30
# 208                               8.30                    1.30
# 262                               9.90                    1.60
# 316                               9.32                    1.60
# 370                               8.39                    1.60
# 424                               7.69                    1.60
# 478                              10.00                    2.20
# 532                               9.39                    2.20
# 586                               8.73                    2.20
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 46                                  8.55         34.8
# 100                                 8.11         36.7
# 154                                 8.67         38.8
# 208                                 8.30         40.5
# 262                                 9.90         41.8
# 316                                 9.32         44.4
# 370                                 8.39         49.3
# 424                                 7.69         53.8
# 478                                10.00         56.9
# 532                                 9.39         60.6
# 586                                 8.73         65.2
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 46                                 ...                                    0.0
# 100                                ...                                    0.0
# 154                                ...                                    0.0
# 208                                ...                                    0.0
# 262                                ...                                    0.0
# 316                                ...                                    0.0
# 370                                ...                                    0.0
# 424                                ...                                    0.0
# 478                                ...                                    0.0
# 532                                ...                                    0.0
# 586                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 46                                                 NaN
# 100                                                NaN
# 154                                                NaN
# 208                                                NaN
# 262                                                NaN
# 316                                                NaN
# 370                                                NaN
# 424                                                NaN
# 478                                                NaN
# 532                                                NaN
# 586                                                NaN
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 46                                      0.0
# 100                                     0.0
# 154                                     0.0
# 208                                     0.0
# 262                                     0.0
# 316                                     0.0
# 370                                     0.0
# 424                                     0.0
# 478                                     0.0
# 532                                     0.0
# 586                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 46                                                 NaN        NaN
# 100                                                NaN        NaN
# 154                                                NaN        NaN
# 208                                                NaN        NaN
# 262                                                NaN        NaN
# 316                                                NaN        NaN
# 370                                                NaN        NaN
# 424                                                NaN        NaN
# 478                                                NaN        NaN
# 532                                                NaN        NaN
# 586                                                NaN        NaN
#      Unnamed: 0  Year     State  State.Minimum.Wage  \
# 49           49  1968  Virginia                 0.0
# 103         103  1969  Virginia                 0.0
# 157         157  1970  Virginia                 0.0
# 211         211  1971  Virginia                 0.0
# 265         265  1972  Virginia                 0.0
# 319         319  1973  Virginia                 0.0
# 373         373  1974  Virginia                 0.0
# 427         427  1975  Virginia                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 49                               0.0                  1.15
# 103                              0.0                  1.15
# 157                              0.0                  1.30
# 211                              0.0                  1.30
# 265                              0.0                  1.60
# 319                              0.0                  1.60
# 373                              0.0                  1.60
# 427                              0.0                  1.60
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 49                                8.55                    1.15
# 103                               8.11                    1.15
# 157                               8.67                    1.30
# 211                               8.30                    1.30
# 265                               9.90                    1.60
# 319                               9.32                    1.60
# 373                               8.39                    1.60
# 427                               7.69                    1.60
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 49                                  8.55         34.8
# 103                                 8.11         36.7
# 157                                 8.67         38.8
# 211                                 8.30         40.5
# 265                                 9.90         41.8
# 319                                 9.32         44.4
# 373                                 8.39         49.3
# 427                                 7.69         53.8
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 49                                 ...                                    0.0
# 103                                ...                                    0.0
# 157                                ...                                    0.0
# 211                                ...                                    0.0
# 265                                ...                                    0.0
# 319                                ...                                    0.0
# 373                                ...                                    0.0
# 427                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 49                                                 0.0
# 103                                                0.0
# 157                                                0.0
# 211                                                0.0
# 265                                                0.0
# 319                                                0.0
# 373                                                0.0
# 427                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 49                                      0.0
# 103                                     0.0
# 157                                     0.0
# 211                                     0.0
# 265                                     0.0
# 319                                     0.0
# 373                                     0.0
# 427                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 49                                                 0.0        NaN
# 103                                                0.0        NaN
# 157                                                0.0        NaN
# 211                                                0.0        NaN
# 265                                                0.0        NaN
# 319                                                0.0        NaN
# 373                                                0.0        NaN
# 427                                                0.0        NaN

# %%
for state, data in grouped_issues:
    if data['State.Minimum.Wage.2020.Dollars'].sum() != 0.0:
        print("Not all rows have 0 values")

# %%
for state, data in df.groupby("State")[["State", "State.Minimum.Wage.2020.Dollars"]]:
    if data['State.Minimum.Wage.2020.Dollars'].sum() != 0.0:
        print("Not all rows have 0 values")
# Out:
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
# Not all rows have 0 values
